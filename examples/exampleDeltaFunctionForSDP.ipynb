# %%
LoadPackage( "QGNAG" );
# Out:
# true

# %%
zeroF := Elements(GF(4))[1];;
oneF := Elements(GF(4))[2];;
w := Elements(GF(4))[3];;
w2 := Elements(GF(4))[4];;

# %%
r := ElementSDP( w, 4);
s := ElementSDP( w2, 3);
t := ElementSDP(zeroF, 2);
u := ElementSDP(oneF, 5);
# Out:
# ( Z(2^2) , 4 )
# ( Z(2^2)^2 , 3 )
# ( 0*Z(2) , 2 )
# ( Z(2)^0 , 5 )

# %%
# Creamos la función delta_0
delta_w_4 := DeltaFunctionForSDP(r);;
Print("---------------------------------------------\n");
Print("Evaluaciones de D_", r,"\n");
Print("D_", r, r, " = ", delta_w_4( r ), "\n");   # debe dar 1
Print("D_", r, s, " = ", delta_w_4( s ), "\n");   # debe dar 0
Print("D_", r, t, " = ", delta_w_4( t ), "\n");   # debe dar 0
Print("D_", r, u, " = ", delta_w_4( u ), "\n");   # debe dar 0
Print("---------------------------------------------\n");
# Out:
# ---------------------------------------------
# Evaluaciones de D_( ω , 4 )
# D_( ω , 4 )( ω , 4 ) = 1
# D_( ω , 4 )( ω^2 , 3 ) = 0
# D_( ω , 4 )( 0 , 2 ) = 0
# D_( ω , 4 )( 1 , 5 ) = 0
# ---------------------------------------------

# %%
# Creamos la función delta_1
delta_w2_3 := DeltaFunctionForSDP(s);;
Print("---------------------------------------------\n");
Print("Evaluaciones de D_", s,"\n");
Print("D_", s, r, " = ", delta_w2_3( r ), "\n");   # debe dar 0
Print("D_", s, s, " = ", delta_w2_3( s ), "\n");   # debe dar 1
Print("D_", s, t, " = ", delta_w2_3( t ), "\n");   # debe dar 0
Print("D_", s, u, " = ", delta_w2_3( u ), "\n");   # debe dar 0
Print("---------------------------------------------\n");
# Out:
# ---------------------------------------------
# Evaluaciones de D_( ω^2 , 3 )
# D_( ω^2 , 3 )( ω , 4 ) = 0
# D_( ω^2 , 3 )( ω^2 , 3 ) = 1
# D_( ω^2 , 3 )( 0 , 2 ) = 0
# D_( ω^2 , 3 )( 1 , 5 ) = 0
# ---------------------------------------------

# %%
# Creamos la función delta_w
delta_0_2 := DeltaFunctionForSDP(t);;
Print("---------------------------------------------\n");
Print("Evaluaciones de D_(0, 2)\n");
Print("D_", t, r, " = ", delta_0_2( r ), "\n");   # debe dar 0
Print("D_", t, s, " = ", delta_0_2( s ), "\n");   # debe dar 0
Print("D_", t, t, " = ", delta_0_2( t ), "\n");   # debe dar 1
Print("D_", t, u, " = ", delta_0_2( u ), "\n");   # debe dar 0
Print("---------------------------------------------\n");
# Out:
# ---------------------------------------------
# Evaluaciones de D_(0, 2)
# D_( 0 , 2 )( ω , 4 ) = 0
# D_( 0 , 2 )( ω^2 , 3 ) = 0
# D_( 0 , 2 )( 0 , 2 ) = 1
# D_( 0 , 2 )( 1 , 5 ) = 0
# ---------------------------------------------

# %%
# Creamos la función delta_w2
delta_1_5 := DeltaFunctionForSDP(u);;
Print("---------------------------------------------\n");
Print("Evaluaciones de D_", u,"\n");
Print("D_", u, r, " = ", delta_1_5( r ), "\n");   # debe dar 0
Print("D_", u, s, " = ", delta_1_5( s ), "\n");   # debe dar 0
Print("D_", u, t, " = ", delta_1_5( t ), "\n");   # debe dar 0
Print("D_", u, u, " = ", delta_1_5( u ), "\n");   # debe dar 1
Print("---------------------------------------------\n");
# Out:
# ---------------------------------------------
# Evaluaciones de D_( 1 , 5 )
# D_( 1 , 5 )( ω , 4 ) = 0
# D_( 1 , 5 )( ω^2 , 3 ) = 0
# D_( 1 , 5 )( 0 , 2 ) = 0
# D_( 1 , 5 )( 1 , 5 ) = 1
# ---------------------------------------------
