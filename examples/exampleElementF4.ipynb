# %%
LoadPackage( "QGNAG" );
# Out:
# true

# %%
QGNAG.Config;
# Out:
# rec( m := 2, verbose := false )

# %%
w := Elements(GF(4))[3];;
w2 := Elements(GF(4))[4];;

# %%
w=w2;
# Out:
# false

# %%
r:=ElementFq(w);
s:=ElementFq(w2);
# Out:
# Z(2^2)
# Z(2^2)^2

# %%
t:=ElementFq("g");
# Out:
# Error, no method found! For debugging hints type ?Recovery from NoMethodFound
# Error, no 1st choice method found for `OneMutable' on 1 arguments at /home/juandavid/Descargas/gap-4.13.1/lib/methsel2.g:250 called from
# OneOp( elm ) at /home/juandavid/Descargas/gap-4.13.1/lib/arith.gi:293 called from
# One( Representative( coll ) ) at /home/juandavid/Descargas/gap-4.13.1/lib/field.gi:24 called from
# DefaultFieldByGenerators( arg[1] ) at /home/juandavid/Descargas/gap-4.13.1/lib/field.gi:121 called from
# DefaultField( [ f ] ) at /home/juandavid/Descargas/gap-4.13.1/pkg/qgnag/gap/F4element.gi:4 called from
# <function "ElementFq">( <arguments> )
#  called from read-eval loop at stream:1

# %%
TypeObj(r);
# Out:
# <Type: (F4Family, [ IsComponentObjectRep, IsAttributeStoringRep, IsExtLElement\, ... ]), data: fail>

# %%
IsElementFqObj(r);
# Out:
# true

# %%
rs:=r*s;
# Out:
# Z(2)^0

# %%
Print(rs);
# Out:
# 1

# %%
FieldPart(rs);
Alias(rs);
# Out:
# Z(2)^0
# "1"

# %%
r;
Inverse(r);
r^-1;
Inverse(r)^-2;
# Out:
# Z(2^2)
# Z(2^2)^2
# Z(2^2)^2
# Z(2^2)^2

# %%
One(r);
# Out:
# Z(2)^0

# %%
?IsFFE
# Out:
# Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap59.html#X7D3DF32C84FEBD25">IsFFE</a><br/>Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap44.html#X84B36A827E5EFC35">IsFFEMatrixGroup</a><br/>Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap59.html#X7D3DF32C84FEBD25">IsFFECollection</a><br/>Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap59.html#X7D3DF32C84FEBD25">IsFFECollColl</a><br/>Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap59.html#X7D3DF32C84FEBD25">IsFFECollCollColl</a><br/>

# %%
IsFFE(w);
# Out:
# true

# %%
IsFFE(w2);
# Out:
# true

# %%
ElementSDP(w,4);
# Out:
# Error, QGNAG modulus is not initialized. Call QGNAGSetModulus(m) first. at /home/juandavid/Descargas/gap-4.13.1/pkg/qgnag/gap/semidirectproduct.gi:85 called from
# <function "ElementSDP">( <arguments> )
#  called from read-eval loop at stream:1

# %%
QGNAGSetModulus(3);

# %%
ElementSDP(w,4);
# Out:
# ( Z(2^2) , 1 )

# %%
act1:=ElementSDP( w, 4 ) * w;
act2:=ElementSDP( w2, 3 ) * w;
# Out:
# Z(2^2)
# 0*Z(2)

# %%
Print(act1);
# Out:
# ζ_4

# %%
Print(act2);
# Out:
# 0

# %%
#GetElementsOfG:=function()
#    local l, k, p, elmsofG;
#    elmsofG:=[];;
#    for l in Elements(GF(ConfigSDP.p)) do
#        for k in [0..(ConfigSDP.m-1)] do
#            Add(elmsofG, ElementSDP(l, k));
#        od;
#    od;
#    return elmsofG;
#end;

# %%
Alias(GetElementsOfG()[3]);
