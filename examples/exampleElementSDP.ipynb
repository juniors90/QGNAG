# %%
LoadPackage( "QGNAG" );
# Out:
# true

# %%
ConfigSDP;
# Out:
# rec( m := 6, p := 4 )

# %%
w := Elements(GF(4))[3];;
w2 := Elements(GF(4))[4];;

# %%
r:=ElementSDP(w,4);
s:=ElementSDP(w2,3);
# Out:
# ( Z(2^2) , 4 )
# ( Z(2^2)^2 , 3 )

# %%
r=s;
# Out:
# false

# %%
t:=ElementSDP(w,"g");
# Out:
# Error, cyclic part must be an integer at /home/juandavid/Descargas/gap-4.13.1/pkg/qgnag/gap/semidirectproduct.gi:60 called from
# <function "ElementSDP">( <arguments> )
#  called from read-eval loop at stream:1

# %%
TypeObj(r);
# Out:
# <Type: (SDPFamily, [ IsComponentObjectRep, IsAttributeStoringRep, IsExtLElemen\t, ... ]), data: fail>

# %%
IsElementSDPObj(r);
# Out:
# true

# %%
rs:=r*s;
# Out:
# ( Z(2^2)^2 , 1 )

# %%
Print(rs);
# Out:
# ( ω^2 , 1 )

# %%
FieldPart(rs);
CyclicPart(rs);
Alias(rs);
IsDistinguishedElement(rs);
# Out:
# Z(2^2)^2
# 1
# "( ω^2 , 1 )"
# true

# %%
ChiForSemidirectProduct(r);
ChiForSemidirectProduct(s);
ChiForSemidirectProduct(rs);
# Out:
# 1
# -1
# -1

# %%
r;
Inverse(r);
r^-1;
Inverse(r)^-2;
# Out:
# ( Z(2^2) , 4 )
# ( Z(2)^0 , 2 )
# ( Z(2)^0 , 2 )
# ( Z(2)^0 , 2 )

# %%
One(r);
# Out:
# ( Z(2)^0 , 1 )

# %%
?IsFFE
# Out:
# Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap59.html#X7D3DF32C84FEBD25">IsFFE</a><br/>Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap44.html#X84B36A827E5EFC35">IsFFEMatrixGroup</a><br/>Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap59.html#X7D3DF32C84FEBD25">IsFFECollection</a><br/>Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap59.html#X7D3DF32C84FEBD25">IsFFECollColl</a><br/>Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap59.html#X7D3DF32C84FEBD25">IsFFECollCollColl</a><br/>

# %%
IsFFE(w);
# Out:
# true

# %%
IsFFE(w2);
# Out:
# true

# %%
w * r;
w * s;
w * rs;
w2 * r;
w2 * s;
w2 * rs;
# Out:
# Error, no method found! For debugging hints type ?Recovery from NoMethodFound
# Error, no 1st choice method found for `*' on 2 arguments at /home/juandavid/Descargas/gap-4.13.1/lib/methsel2.g:250 called from
# <function "HANDLE_METHOD_NOT_FOUND">( <arguments> )
#  called from read-eval loop at stream:1
# Error, no method found! For debugging hints type ?Recovery from NoMethodFound
# Error, no 1st choice method found for `*' on 2 arguments at /home/juandavid/Descargas/gap-4.13.1/lib/methsel2.g:250 called from
# <function "HANDLE_METHOD_NOT_FOUND">( <arguments> )
#  called from read-eval loop at stream:2
# Error, no method found! For debugging hints type ?Recovery from NoMethodFound
# Error, no 1st choice method found for `*' on 2 arguments at /home/juandavid/Descargas/gap-4.13.1/lib/methsel2.g:250 called from
# <function "HANDLE_METHOD_NOT_FOUND">( <arguments> )
#  called from read-eval loop at stream:3
# Error, no method found! For debugging hints type ?Recovery from NoMethodFound
# Error, no 1st choice method found for `*' on 2 arguments at /home/juandavid/Descargas/gap-4.13.1/lib/methsel2.g:250 called from
# <function "HANDLE_METHOD_NOT_FOUND">( <arguments> )
#  called from read-eval loop at stream:4
# Error, no method found! For debugging hints type ?Recovery from NoMethodFound
# Error, no 1st choice method found for `*' on 2 arguments at /home/juandavid/Descargas/gap-4.13.1/lib/methsel2.g:250 called from
# <function "HANDLE_METHOD_NOT_FOUND">( <arguments> )
#  called from read-eval loop at stream:5
# Error, no method found! For debugging hints type ?Recovery from NoMethodFound
# Error, no 1st choice method found for `*' on 2 arguments at /home/juandavid/Descargas/gap-4.13.1/lib/methsel2.g:250 called from
# <function "HANDLE_METHOD_NOT_FOUND">( <arguments> )
#  called from read-eval loop at stream:6
