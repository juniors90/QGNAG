# %%
LoadPackage( "QGNAG" );
# Out:
# true

# %%
###########################################################
# Example Usage
###########################################################

# Define the factors
myGroupElement := [0, 1, 0];
myVSElement := 1;
# Out:
# [ 0, 1, 0 ]
# 1

# %%
# Create the tensor element
t := TensorElement(myGroupElement, myVSElement);
# Out:
# ([ 0, 1, 0 ]) ⊗ 1

# %%
t;
# Out:
# ([ 0, 1, 0 ]) ⊗ 1

# %%
String(t);
# Out:
# "([ 0, 1, 0 ]) ⊗ 1"

# %%
GroupElement(t);
# Out:
# [ 0, 1, 0 ]

# %%
VectorSpaceElement(t);
# Out:
# 1

# %% [markdown]
# ## Combinado

# %%
zeroGF := Elements(GF(4))[1];;

# %%
g1:=ElementSDP(zeroGF, 0);
g2:=ElementSDP(zeroGF, 1);
g3:=ElementSDP(zeroGF, 2);
# Out:
# ( 0*Z(2) , 0 )
# ( 0*Z(2) , 1 )
# ( 0*Z(2) , 2 )

# %%
myVSElement:=1;
# Out:
# 1

# %%
# Create the tensor element
w1 := TensorElement(g1, myVSElement);
w2 := TensorElement(g2, myVSElement);
w3 := TensorElement(g3, myVSElement);
# Out:
# (( 0*Z(2) , 0 )) ⊗ 1
# (( 0*Z(2) , 1 )) ⊗ 1
# (( 0*Z(2) , 2 )) ⊗ 1

# %%
Print(w1);
# Out:
# (( 0 , 0 )) ⊗ 1

# %%
Print(w1);
# Out:
# (( 0 , 0 )) ⊗ 1

# %%
Print(w2);
# Out:
# (( 0 , 1 )) ⊗ 1

# %%
Print(w3);
# Out:
# (( 0 , 2 )) ⊗ 1
