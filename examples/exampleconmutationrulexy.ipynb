# %%
LoadPackage( "QGNAG" );
# Out:
# true

# %%
xIndex := [ 1..4 ];;
deltaIndex := [ 9..32 ];;
yIndex := [ 33..36 ];;

# %%
groupIndex:=[ 
    [  ], 
    [ 5 ], 
    [ 6 ], 
    [ 5, 6 ], 
    [ 6, 6 ], 
    [ 5, 6, 6 ], 
    [ 8 ], 
    [ 8, 5 ],   
    [ 6, 7 ], 
    [ 5, 6, 8 ], 
    [ 6, 7, 6 ], 
    [ 5, 6, 6, 7 ], 
    [ 7 ], 
    [ 5, 8 ],   
    [ 7, 6 ], 
    [ 5, 6, 7 ], 
    [ 6, 6, 8 ], 
    [ 5, 6, 6, 7, 8 ], 
    [ 7, 8 ], 
    [ 5, 7 ],   
    [ 6, 8 ], 
    [ 5, 7, 6 ], 
    [ 6, 6, 7 ], 
    [ 5, 6, 6, 8 ] 
];
# Out:
# [ [  ], [ 5 ], [ 6 ], [ 5, 6 ], [ 6, 6 ], [ 5, 6, 6 ], [ 8 ], [ 8, 5 ],   [ 6, 7 ], [ 5, 6, 8 ], [ 6, 7, 6 ], [ 5, 6, 6, 7 ], [ 7 ], [ 5, 8 ],   [ 7, 6 ], [ 5, 6, 7 ], [ 6, 6, 8 ], [ 5, 6, 6, 7, 8 ], [ 7, 8 ], [ 5, 7 ],   [ 6, 8 ], [ 5, 7, 6 ], [ 6, 6, 7 ], [ 5, 6, 6, 8 ] ]

# %%
w := Elements(GF(4))[3];;
w2 := Elements(GF(4))[4];;

# %%
i:=ElementF4(w);
j:=ElementF4(w2);
# Out:
# Z(2^2)
# Z(2^2)^2

# %%
gensA := List(Elements( GF( ConfigSDP.p ) ), x -> ElementF4(x));
# Out:
# [ 0*Z(2), Z(2)^0, Z(2^2), Z(2^2)^2 ]

# %%
Print(gensA);
# Out:
# [ 0, 1, ω, ω^2 ]

# %%
i in gensA;
# Out:
# true

# %%
GetConmutationRuleOnB4w(i, j, xIndex, groupIndex, deltaIndex, yIndex);
# Out:
# [ [ [ 36, 3 ], [ 3, 34 ], [ 5, 8, 28 ], [ 5, 8, 31 ], [ 5, 8, 15 ],       [ 5, 8, 18 ], [ 5, 8, 11 ], [ 5, 8, 14 ] ],   [ 1, 1, -1, 1, 1, -1, 1, -1 ] ]
