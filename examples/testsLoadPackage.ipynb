# %%
LoadPackage( "QGNAG" );
# Out:
# true

# %%
A := [ [1,2], [3,4] ];
# Out:
# [ [ 1, 2 ], [ 3, 4 ] ]

# %%
B := [ [ 0, 5 ], [ 6, 7 ] ];
# Out:
# [ [ 0, 5 ], [ 6, 7 ] ]

# %%
Display(TensorProductMatrix( A, B ));
# Out:
# [ [   0,   0,   5,  10 ],
#   [   0,   0,  15,  20 ],
#   [   6,  12,   7,  14 ],
#   [  18,  24,  21,  28 ] ]

# %%
Display(KroneckerProduct( A, B ));
# Out:
# [ [   0,   5,   0,  10 ],
#   [   6,   7,  12,  14 ],
#   [   0,  15,   0,  20 ],
#   [  18,  21,  24,  28 ] ]

# %%
TensorProductMatrix( A, B ) = KroneckerProduct(B, A);
# Out:
# true

# %%
TensorProductMatrix( B, A );
# Out:
# [ [ 0, 5, 0, 10 ], [ 6, 7, 12, 14 ], [ 0, 15, 0, 20 ], [ 18, 21, 24, 28 ] ]

# %%
NrRows(TensorProductMatrix( B, A ));
# Out:
# 4
