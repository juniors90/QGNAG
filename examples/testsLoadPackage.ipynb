# %%
LoadPackage( "QGNAG" );
# Out:
# true

# %%
?FreeAssociativeAlgebraWithOne
# Out:
# Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap62.html#X845A777584A7D711">FreeAssociativeAlgebraWithOne for ring, rank (and name)</a>

# %%
A:= FreeAlgebraWithOne( GF(5), "a", "b" );
g:= GeneratorsOfAlgebra( A );
# Out:
# <algebra-with-one over GF(2), with 2 generators>
# [ (Z(2)^0)*<identity ...>, (Z(2)^0)*a, (Z(2)^0)*b ]

# %%
A:= FreeAlgebraWithOne( ZmodnZ(5), "a", "b" );
g:= GeneratorsOfAlgebra( A );
# Out:
# <algebra-with-one over GF(5), with 2 generators>
# [ (Z(5)^0)*<identity ...>, (Z(5)^0)*a, (Z(5)^0)*b ]

# %%
?DeclareRepresentation
# Out:
# Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap13.html#X7C81FB2682AE54CD">DeclareRepresentation</a><br/>Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap79.html#X7837CA9A83D93B38">DeclareRepresentation belongs to implementation part</a><br/>Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap80.html#X8111D831783C9ED6">DeclareRepresentation example</a><br/>
